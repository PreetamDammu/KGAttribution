# %%
import pandas as pd

# %%
df = pd.read_pickle('outputs/wikiqa_test_answers_KGmid_coref_with_paths20.pkl')

# %%
df
# Out:
#                                              ipSentence  \
# 0     African immigration to the United States refer...
# 1     The term African in the scope of this article ...
# 2     From the Immigration and Nationality Act of 19...
# 3     African immigrants in the United States come f...
# 4     They include people from different national, l...
# ...                                                 ...
# 6160  The word can also be used for other female equ...
# 6161           A broodmare is a mare used for breeding.
# 6162       A horse's female parent is known as its dam.
# 6163  An adult male horse is called a stallion , or,...
# 6164  Occasionally the term "horse" is used in a res...
#
#                                        ipSentence_coref  \
# 0      African immigration to the United States refe...
# 1      The term African in the scope of this article...
# 2      From the Immigration and Nationality Act of 1...
# 3      African immigrants in the United States come ...
# ...

# %%
len(df.iloc[0]['paths_obtained_labels'])
# Out:
# 4

# %%
len(df.iloc[0]['paths_obtained_labels'][3])
# Out:
# 6

# %%
df.iloc[0]['paths_obtained_labels'][3]
# Out:
# [[('United States of America', 'diplomatic relation', 'Estonia'),
#   ('Immigration to Estonia', 'country', 'Estonia'),
#   ('Immigration to Estonia', 'instance of', 'immigration')],
#  [('Lila Tretikov', 'country of citizenship', 'United States of America'),
#   ('Lila Tretikov', 'significant event', 'immigration')],
#  [('US immigration order strikes against biotech.',
#    'main subject',
#    'United States of America'),
#   ('US immigration order strikes against biotech.',
#    'main subject',
#    'immigration')],
#  [('Carl Friedrich Zimmermann',
#    'country of citizenship',
#    'United States of America'),
#   ('Carl Friedrich Zimmermann', 'significant event', 'immigration')],
#  [('William R. Blair', 'country of citizenship', 'United States of America'),
#   ('William R. Blair', 'significant event', 'immigration')],
#  [('Conférence de presse du Président de la République, Emmanuel Macron avec la Chancelière allemande Angela Merkel à Meseberg',
#    'depicts',
# ...
